# %% [markdown]
# ## Data Quality Assessment in Python

# %% [markdown]
# Simple analysis is carried out in Python to determine the quality of the data.

# %%
#Importing important Data Exporatory Libraries
import matplotlib as plt
import pandas as pd
import numpy as np

# %%
df.isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
#Getting the reguired excel sheet
df = pd.read_excel(r"C:\Users\Sir_Praise\Desktop\transaction data.xlsx")
df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
#df['transaction_id'].duplicated().any()
#df['product_id'].duplicated().any()
#df['customer_id'].duplicated().any()
df['transaction_date'].duplicated().any()
# Out:
# True

# %%
total_null_values = sum(df.isna().sum())
total_null_values
# Out:
# 1542

# %% [markdown]
# CUSTOMER DEMOGRAPHICS DATASET

# %%
cd = pd.read_excel(r"C:\Users\Sir_Praise\Desktop\customer_demograph.xlsx")
cd
# Out:
#       customer_id first_name  last_name  gender  \
# 0             720     Darrel      Canet    Male
# 1            1092     Katlin    Creddon  Female
# 2            3410    Merrili    Brittin  Female
# 3            2413      Abbey     Murrow    Male
# 4             658       Donn    Bonnell    Male
# ...           ...        ...        ...     ...
# 3995         3779      Ulick     Daspar       U
# 3996         3883      Nissa     Conrad       U
# 3997         3931      Kylie      Epine       U
# 3998         3935     Teodor  Alfonsini       U
# 3999         3998     Sarene    Woolley       U
#
#       past_3_years_bike_related_purchases        DOB  Ages  \
# 0                                      67 1931-10-23    89
# 1                                      56 1935-08-22    85
# 2                                      93 1940-09-22    80
# 3                                      27 1943-08-11    77
# 4                                      38 1944-01-24    76
# ...

# %%
#cd['first_name'].duplicated().any()
cd['last_name'].duplicated().any()
# Out:
# True

# %%
cd.isna().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# Ages                                     0
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
total_null_values_cd = sum(cd.isna().sum())
total_null_values_cd
# Out:
# 1763

# %% [markdown]
# CUSTOMER ADDRESS

# %%
ca = pd.read_excel(r"C:\Users\Sir_Praise\Desktop\customer_address.xlsx")
ca
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
ca["customer_id"].duplicated().any()
# Out:
# False

# %%
ca.isna().sum() #the customer address dataset is free from missing values.
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64
